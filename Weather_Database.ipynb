# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key

print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=96634bf652796c6f2292e5fece09e188

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | katherine
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | lahaina
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | saldanha
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | portland
# Processing Record 14 of Set 1 | tiksi
# Processing Record 15 of Set 1 | shushtar
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 1 | capinopolis
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | port-gentil
# Processing Record 21 of Set 1 | hamilton
# Processing Record 22 of Set 1 | berlevag
# Processing Record 23 of Set 1 | kapoeta
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | pangnirtung
# Processing Record 26 of Set 1 | vanimo
# Processing Record 27 of Set 1 | kavieng
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | epe
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | bluefields
# Processing Record 36 of Set 1 | bubaque
# Processing Record 37 of Set 1 | katsuura
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | alta floresta
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | adre
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | khartoum
# Processing Record 45 of Set 1 | boyolangu
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | vila franca do campo
# Processing Record 48 of Set 1 | hirara
# Processing Record 49 of Set 1 | horsham
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | yerbogachen
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | avera
# Processing Record 8 of Set 2 | dzhebariki-khaya
# Processing Record 9 of Set 2 | ledyard
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 2 | dalbandin
# Processing Record 13 of Set 2 | tigil
# Processing Record 14 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 2 | fortuna
# Processing Record 18 of Set 2 | acapulco
# Processing Record 19 of Set 2 | yenagoa
# Processing Record 20 of Set 2 | saint-francois
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | souillac
# Processing Record 23 of Set 2 | vardo
# Processing Record 24 of Set 2 | port hedland
# Processing Record 25 of Set 2 | hovd
# Processing Record 26 of Set 2 | busselton
# Processing Record 27 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | baykit
# Processing Record 32 of Set 2 | kavaratti
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | port keats
# Processing Record 35 of Set 2 | turayf
# Processing Record 36 of Set 2 | asau
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | poitiers
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | atar
# Processing Record 41 of Set 2 | camana
# Processing Record 42 of Set 2 | batagay-alyta
# Processing Record 43 of Set 2 | gubkinskiy
# Processing Record 44 of Set 2 | clyde river
# Processing Record 45 of Set 2 | mahebourg
# Processing Record 46 of Set 2 | caravelas
# Processing Record 47 of Set 2 | florianopolis
# Processing Record 48 of Set 2 | litomysl
# Processing Record 49 of Set 2 | meulaboh
# Processing Record 50 of Set 2 | richards bay
# Processing Record 1 of Set 3 | khani
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | kirakira
# Processing Record 7 of Set 3 | camacha
# Processing Record 8 of Set 3 | bilibino
# Processing Record 9 of Set 3 | ahipara
# Processing Record 10 of Set 3 | cagliari
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | tiarei
# Processing Record 14 of Set 3 | qaanaaq
# Processing Record 15 of Set 3 | broome
# Processing Record 16 of Set 3 | shawnee
# Processing Record 17 of Set 3 | broken hill
# Processing Record 18 of Set 3 | weligama
# Processing Record 19 of Set 3 | cape town
# Processing Record 20 of Set 3 | jishou
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 3 | ladario
# Processing Record 24 of Set 3 | barra do garcas
# Processing Record 25 of Set 3 | pingdingshan
# Processing Record 26 of Set 3 | sao joao da barra
# Processing Record 27 of Set 3 | lorengau
# Processing Record 28 of Set 3 | lagoa
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | lompoc
# Processing Record 31 of Set 3 | inza
# Processing Record 32 of Set 3 | riyadh
# Processing Record 33 of Set 3 | saint-philippe
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | moron
# Processing Record 38 of Set 3 | svecha
# Processing Record 39 of Set 3 | norman wells
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | torbay
# Processing Record 42 of Set 3 | kapatalan
# Processing Record 43 of Set 3 | chuy
# Processing Record 44 of Set 3 | requena
# Processing Record 45 of Set 3 | brownsville
# Processing Record 46 of Set 3 | jambi
# Processing Record 47 of Set 3 | kloulklubed
# Processing Record 48 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 3 | sabae
# Processing Record 50 of Set 3 | santa engracia
# Processing Record 1 of Set 4 | quibdo
# Processing Record 2 of Set 4 | naryan-mar
# Processing Record 3 of Set 4 | mawlaik
# Processing Record 4 of Set 4 | henties bay
# Processing Record 5 of Set 4 | port hardy
# Processing Record 6 of Set 4 | san mateo del mar
# Processing Record 7 of Set 4 | fare
# Processing Record 8 of Set 4 | kearney
# Processing Record 9 of Set 4 | tselinnoye
# Processing Record 10 of Set 4 | chernyy yar
# Processing Record 11 of Set 4 | aswan
# Processing Record 12 of Set 4 | mahuva
# Processing Record 13 of Set 4 | chapais
# Processing Record 14 of Set 4 | kizukuri
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | guia lopes da laguna
# Processing Record 17 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 4 | mar del plata
# Processing Record 19 of Set 4 | taoudenni
# Processing Record 20 of Set 4 | jerez
# Processing Record 21 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 4 | slave lake
# Processing Record 23 of Set 4 | matagami
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | lavrentiya
# Processing Record 26 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | nelson bay
# Processing Record 28 of Set 4 | bandarbeyla
# Processing Record 29 of Set 4 | ostrovskoye
# Processing Record 30 of Set 4 | nata
# Processing Record 31 of Set 4 | cap malheureux
# Processing Record 32 of Set 4 | pilikwe
# Processing Record 33 of Set 4 | te anau
# Processing Record 34 of Set 4 | tuktoyaktuk
# Processing Record 35 of Set 4 | luanda
# Processing Record 36 of Set 4 | kieta
# Processing Record 37 of Set 4 | upington
# Processing Record 38 of Set 4 | oistins
# Processing Record 39 of Set 4 | iquitos
# Processing Record 40 of Set 4 | chupei
# City not found. Skipping...
# Processing Record 41 of Set 4 | codrington
# Processing Record 42 of Set 4 | provideniya
# Processing Record 43 of Set 4 | poronaysk
# Processing Record 44 of Set 4 | kidal
# Processing Record 45 of Set 4 | srednekolymsk
# Processing Record 46 of Set 4 | vao
# Processing Record 47 of Set 4 | longkou
# Processing Record 48 of Set 4 | mastic beach
# Processing Record 49 of Set 4 | constitucion
# Processing Record 50 of Set 4 | puerto quijarro
# Processing Record 1 of Set 5 | marawi
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | malakal
# Processing Record 4 of Set 5 | port said
# Processing Record 5 of Set 5 | okha
# Processing Record 6 of Set 5 | klaksvik
# Processing Record 7 of Set 5 | warangal
# Processing Record 8 of Set 5 | cine
# Processing Record 9 of Set 5 | port macquarie
# Processing Record 10 of Set 5 | dingle
# Processing Record 11 of Set 5 | shirokiy
# Processing Record 12 of Set 5 | vaasa
# Processing Record 13 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 14 of Set 5 | port lincoln
# Processing Record 15 of Set 5 | sur
# Processing Record 16 of Set 5 | khrebtovaya
# Processing Record 17 of Set 5 | taman
# Processing Record 18 of Set 5 | kalabo
# Processing Record 19 of Set 5 | agva
# City not found. Skipping...
# Processing Record 20 of Set 5 | linxia
# Processing Record 21 of Set 5 | omsukchan
# Processing Record 22 of Set 5 | lazaro cardenas
# Processing Record 23 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 5 | chokurdakh
# Processing Record 25 of Set 5 | calvinia
# Processing Record 26 of Set 5 | vostok
# Processing Record 27 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 5 | skiros
# City not found. Skipping...
# Processing Record 29 of Set 5 | oshkosh
# Processing Record 30 of Set 5 | tadine
# Processing Record 31 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 5 | zaragoza
# Processing Record 33 of Set 5 | axim
# Processing Record 34 of Set 5 | pangai
# Processing Record 35 of Set 5 | thompson
# Processing Record 36 of Set 5 | kelvington
# Processing Record 37 of Set 5 | vila velha
# Processing Record 38 of Set 5 | turukhansk
# Processing Record 39 of Set 5 | carnarvon
# Processing Record 40 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 5 | huangnihe
# Processing Record 42 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 5 | aklavik
# Processing Record 44 of Set 5 | nyamati
# Processing Record 45 of Set 5 | khatanga
# Processing Record 46 of Set 5 | shingu
# Processing Record 47 of Set 5 | redcliffe
# Processing Record 48 of Set 5 | new albany
# Processing Record 49 of Set 5 | ekhabi
# Processing Record 50 of Set 5 | arraial do cabo
# Processing Record 1 of Set 6 | san carlos de bariloche
# Processing Record 2 of Set 6 | fukuyama
# Processing Record 3 of Set 6 | port augusta
# Processing Record 4 of Set 6 | kaoma
# Processing Record 5 of Set 6 | caernarfon
# Processing Record 6 of Set 6 | lyubytino
# Processing Record 7 of Set 6 | mogadishu
# Processing Record 8 of Set 6 | raudeberg
# Processing Record 9 of Set 6 | los llanos de aridane
# Processing Record 10 of Set 6 | ekibastuz
# Processing Record 11 of Set 6 | nemuro
# Processing Record 12 of Set 6 | semey
# Processing Record 13 of Set 6 | rawson
# Processing Record 14 of Set 6 | urumqi
# Processing Record 15 of Set 6 | tucurui
# Processing Record 16 of Set 6 | pacifica
# Processing Record 17 of Set 6 | batagay
# Processing Record 18 of Set 6 | coulihaut
# City not found. Skipping...
# Processing Record 19 of Set 6 | bay-khaak
# Processing Record 20 of Set 6 | road town
# Processing Record 21 of Set 6 | san andres
# Processing Record 22 of Set 6 | laguna
# Processing Record 23 of Set 6 | sorland
# Processing Record 24 of Set 6 | san policarpo
# Processing Record 25 of Set 6 | isiro
# Processing Record 26 of Set 6 | sao jose de ribamar
# Processing Record 27 of Set 6 | noyabrsk
# Processing Record 28 of Set 6 | severo-kurilsk
# Processing Record 29 of Set 6 | ketchikan
# Processing Record 30 of Set 6 | lubao
# Processing Record 31 of Set 6 | sitka
# Processing Record 32 of Set 6 | victoria
# Processing Record 33 of Set 6 | saint george
# Processing Record 34 of Set 6 | san juan
# Processing Record 35 of Set 6 | kaeng khoi
# Processing Record 36 of Set 6 | palana
# Processing Record 37 of Set 6 | tabou
# Processing Record 38 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 39 of Set 6 | jalu
# Processing Record 40 of Set 6 | cherskiy
# Processing Record 41 of Set 6 | nome
# Processing Record 42 of Set 6 | ambanja
# Processing Record 43 of Set 6 | la serena
# Processing Record 44 of Set 6 | dunda
# Processing Record 45 of Set 6 | halifax
# Processing Record 46 of Set 6 | rzhaksa
# Processing Record 47 of Set 6 | merauke
# Processing Record 48 of Set 6 | hobyo
# Processing Record 49 of Set 6 | havelock
# Processing Record 50 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | zyryanka
# Processing Record 2 of Set 7 | tamandare
# Processing Record 3 of Set 7 | ilulissat
# Processing Record 4 of Set 7 | kaduna
# Processing Record 5 of Set 7 | aykhal
# Processing Record 6 of Set 7 | katobu
# Processing Record 7 of Set 7 | geraldton
# Processing Record 8 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 9 of Set 7 | vilhena
# Processing Record 10 of Set 7 | indiana
# Processing Record 11 of Set 7 | vanderhoof
# Processing Record 12 of Set 7 | airai
# Processing Record 13 of Set 7 | kupang
# Processing Record 14 of Set 7 | la ronge
# Processing Record 15 of Set 7 | tomelloso
# Processing Record 16 of Set 7 | novoagansk
# Processing Record 17 of Set 7 | samarai
# Processing Record 18 of Set 7 | kizema
# Processing Record 19 of Set 7 | komsomolskiy
# Processing Record 20 of Set 7 | nalut
# Processing Record 21 of Set 7 | bathsheba
# Processing Record 22 of Set 7 | talnakh
# Processing Record 23 of Set 7 | mehamn
# Processing Record 24 of Set 7 | nuuk
# Processing Record 25 of Set 7 | belmonte
# Processing Record 26 of Set 7 | dikson
# Processing Record 27 of Set 7 | anadyr
# Processing Record 28 of Set 7 | faanui
# Processing Record 29 of Set 7 | urusha
# Processing Record 30 of Set 7 | le port
# Processing Record 31 of Set 7 | newcastle
# Processing Record 32 of Set 7 | kaseda
# Processing Record 33 of Set 7 | bayan
# Processing Record 34 of Set 7 | antsohihy
# Processing Record 35 of Set 7 | dunn
# Processing Record 36 of Set 7 | mount gambier
# Processing Record 37 of Set 7 | paka
# Processing Record 38 of Set 7 | atlantic city
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 7 | haines junction
# Processing Record 42 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 43 of Set 7 | luis correia
# Processing Record 44 of Set 7 | balykshi
# Processing Record 45 of Set 7 | muros
# Processing Record 46 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 47 of Set 7 | matamoros
# Processing Record 48 of Set 7 | athabasca
# Processing Record 49 of Set 7 | champasak
# Processing Record 50 of Set 7 | namibe
# Processing Record 1 of Set 8 | biak
# Processing Record 2 of Set 8 | umm lajj
# Processing Record 3 of Set 8 | paamiut
# Processing Record 4 of Set 8 | magdagachi
# Processing Record 5 of Set 8 | kataysk
# Processing Record 6 of Set 8 | nampula
# Processing Record 7 of Set 8 | prince rupert
# Processing Record 8 of Set 8 | sayyan
# Processing Record 9 of Set 8 | bowen
# Processing Record 10 of Set 8 | uto
# Processing Record 11 of Set 8 | ilhabela
# Processing Record 12 of Set 8 | burnie
# Processing Record 13 of Set 8 | hualmay
# Processing Record 14 of Set 8 | bakel
# Processing Record 15 of Set 8 | san pedro
# Processing Record 16 of Set 8 | sohbatpur
# Processing Record 17 of Set 8 | mana
# Processing Record 18 of Set 8 | nanortalik
# Processing Record 19 of Set 8 | roebourne
# Processing Record 20 of Set 8 | namwala
# Processing Record 21 of Set 8 | vestmannaeyjar
# Processing Record 22 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 8 | manzanillo
# Processing Record 24 of Set 8 | palmer
# Processing Record 25 of Set 8 | beringovskiy
# Processing Record 26 of Set 8 | aitape
# Processing Record 27 of Set 8 | eyl
# Processing Record 28 of Set 8 | kurilsk
# Processing Record 29 of Set 8 | shenkursk
# Processing Record 30 of Set 8 | banjar
# Processing Record 31 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 8 | the valley
# Processing Record 33 of Set 8 | samana
# Processing Record 34 of Set 8 | muhoroni
# Processing Record 35 of Set 8 | codroipo
# Processing Record 36 of Set 8 | idritsa
# Processing Record 37 of Set 8 | maku
# Processing Record 38 of Set 8 | sawakin
# Processing Record 39 of Set 8 | auki
# Processing Record 40 of Set 8 | abu zabad
# Processing Record 41 of Set 8 | khandyga
# Processing Record 42 of Set 8 | tuatapere
# Processing Record 43 of Set 8 | ozernovskiy
# Processing Record 44 of Set 8 | fairbanks
# Processing Record 45 of Set 8 | douglas
# Processing Record 46 of Set 8 | xiaoweizhai
# Processing Record 47 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 8 | antofagasta
# Processing Record 49 of Set 8 | cockburn town
# Processing Record 50 of Set 8 | capim grosso
# Processing Record 1 of Set 9 | pangody
# Processing Record 2 of Set 9 | nanpiao
# Processing Record 3 of Set 9 | tilichiki
# Processing Record 4 of Set 9 | lethem
# Processing Record 5 of Set 9 | pak chong
# Processing Record 6 of Set 9 | mackenzie
# Processing Record 7 of Set 9 | metro
# Processing Record 8 of Set 9 | teya
# Processing Record 9 of Set 9 | strazica
# City not found. Skipping...
# Processing Record 10 of Set 9 | aldan
# Processing Record 11 of Set 9 | salalah
# Processing Record 12 of Set 9 | yeppoon
# Processing Record 13 of Set 9 | jeremie
# Processing Record 14 of Set 9 | santa isabel do rio negro
# Processing Record 15 of Set 9 | coihaique
# Processing Record 16 of Set 9 | mountain home
# Processing Record 17 of Set 9 | valera
# Processing Record 18 of Set 9 | nantucket
# Processing Record 19 of Set 9 | alvaraes
# Processing Record 20 of Set 9 | rey bouba
# Processing Record 21 of Set 9 | okhotsk
# Processing Record 22 of Set 9 | tocopilla
# Processing Record 23 of Set 9 | ostrovnoy
# Processing Record 24 of Set 9 | boende
# Processing Record 25 of Set 9 | angoche
# Processing Record 26 of Set 9 | lata
# Processing Record 27 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 9 | comodoro rivadavia
# Processing Record 29 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 30 of Set 9 | kalmunai
# Processing Record 31 of Set 9 | casino
# Processing Record 32 of Set 9 | mago
# Processing Record 33 of Set 9 | tessalit
# Processing Record 34 of Set 9 | shumerlya
# Processing Record 35 of Set 9 | severobaykalsk
# Processing Record 36 of Set 9 | coahuayana
# Processing Record 37 of Set 9 | jaguaribe
# Processing Record 38 of Set 9 | tarata
# Processing Record 39 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 9 | dukat
# Processing Record 41 of Set 9 | manggar
# Processing Record 42 of Set 9 | mackay
# Processing Record 43 of Set 9 | mount isa
# Processing Record 44 of Set 9 | kaka
# Processing Record 45 of Set 9 | maragogi
# Processing Record 46 of Set 9 | flinders
# Processing Record 47 of Set 9 | almeirim
# Processing Record 48 of Set 9 | yulara
# Processing Record 49 of Set 9 | karla
# Processing Record 50 of Set 9 | bogorodskoye
# Processing Record 1 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 10 | fowa
# Processing Record 3 of Set 10 | irbil
# Processing Record 4 of Set 10 | islamabad
# Processing Record 5 of Set 10 | abbeville
# Processing Record 6 of Set 10 | ulladulla
# Processing Record 7 of Set 10 | tura
# Processing Record 8 of Set 10 | goianinha
# Processing Record 9 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 10 | mullovka
# Processing Record 11 of Set 10 | whitehorse
# Processing Record 12 of Set 10 | kitui
# Processing Record 13 of Set 10 | formosa do rio preto
# Processing Record 14 of Set 10 | palora
# Processing Record 15 of Set 10 | high rock
# Processing Record 16 of Set 10 | abu kamal
# Processing Record 17 of Set 10 | coquimbo
# Processing Record 18 of Set 10 | vilyuysk
# Processing Record 19 of Set 10 | huarmey
# Processing Record 20 of Set 10 | nanfeng
# Processing Record 21 of Set 10 | pimenta bueno
# Processing Record 22 of Set 10 | annau
# Processing Record 23 of Set 10 | banda aceh
# Processing Record 24 of Set 10 | kljajicevo
# Processing Record 25 of Set 10 | sayan
# Processing Record 26 of Set 10 | alofi
# Processing Record 27 of Set 10 | puerto pinasco
# City not found. Skipping...
# Processing Record 28 of Set 10 | honningsvag
# Processing Record 29 of Set 10 | majene
# Processing Record 30 of Set 10 | ayan
# Processing Record 31 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 10 | rodeo
# Processing Record 33 of Set 10 | rundu
# Processing Record 34 of Set 10 | huinan
# Processing Record 35 of Set 10 | cayenne
# Processing Record 36 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 10 | dongsheng
# Processing Record 38 of Set 10 | lyubech
# Processing Record 39 of Set 10 | galesong
# Processing Record 40 of Set 10 | bengkulu
# Processing Record 41 of Set 10 | tateyama
# Processing Record 42 of Set 10 | brae
# Processing Record 43 of Set 10 | baiyin
# Processing Record 44 of Set 10 | saint-georges
# Processing Record 45 of Set 10 | beloha
# Processing Record 46 of Set 10 | suzhou
# Processing Record 47 of Set 10 | rincon
# Processing Record 48 of Set 10 | ushtobe
# Processing Record 49 of Set 10 | tautira
# Processing Record 50 of Set 10 | nokaneng
# Processing Record 1 of Set 11 | agirish
# Processing Record 2 of Set 11 | kruisfontein
# Processing Record 3 of Set 11 | ballina
# Processing Record 4 of Set 11 | havoysund
# Processing Record 5 of Set 11 | tairua
# Processing Record 6 of Set 11 | muravlenko
# Processing Record 7 of Set 11 | sibolga
# Processing Record 8 of Set 11 | umm bab
# Processing Record 9 of Set 11 | voh
# Processing Record 10 of Set 11 | bellavista
# Processing Record 11 of Set 11 | moose factory
# Processing Record 12 of Set 11 | koboldo
# City not found. Skipping...
# Processing Record 13 of Set 11 | junin
# Processing Record 14 of Set 11 | formosa
# Processing Record 15 of Set 11 | westport
# Processing Record 16 of Set 11 | praya
# Processing Record 17 of Set 11 | kulhudhuffushi
# Processing Record 18 of Set 11 | shimoda
# Processing Record 19 of Set 11 | aksu
# Processing Record 20 of Set 11 | novovarshavka
# Processing Record 21 of Set 11 | riberalta
# Processing Record 22 of Set 11 | deputatskiy
# Processing Record 23 of Set 11 | buj
# Processing Record 24 of Set 11 | maine-soroa
# Processing Record 25 of Set 11 | ruwi
# Processing Record 26 of Set 11 | ternate
# Processing Record 27 of Set 11 | fayaoue
# Processing Record 28 of Set 11 | zharkent
# Processing Record 29 of Set 11 | slavutych
# Processing Record 30 of Set 11 | fuyu
# Processing Record 31 of Set 11 | birao
# Processing Record 32 of Set 11 | boysun
# Processing Record 33 of Set 11 | ust-nera
# Processing Record 34 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 11 | fallon
# Processing Record 36 of Set 11 | ordzhonikidze
# Processing Record 37 of Set 11 | pavlodar
# Processing Record 38 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 11 | kashi
# Processing Record 40 of Set 11 | xiaoshan
# Processing Record 41 of Set 11 | itarema
# Processing Record 42 of Set 11 | maniitsoq
# Processing Record 43 of Set 11 | porbandar
# Processing Record 44 of Set 11 | porto novo
# Processing Record 45 of Set 11 | quatre cocos
# Processing Record 46 of Set 11 | nigde
# Processing Record 47 of Set 11 | vallenar
# Processing Record 48 of Set 11 | krapivinskiy
# Processing Record 49 of Set 11 | leh
# Processing Record 50 of Set 11 | bethal
# Processing Record 1 of Set 12 | kutum
# Processing Record 2 of Set 12 | monte azul paulista
# Processing Record 3 of Set 12 | kailua
# Processing Record 4 of Set 12 | saint-augustin
# Processing Record 5 of Set 12 | roma
# Processing Record 6 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 7 of Set 12 | buraydah
# Processing Record 8 of Set 12 | safaga
# Processing Record 9 of Set 12 | tucuman
# Processing Record 10 of Set 12 | sivas
# Processing Record 11 of Set 12 | emmauss
# Processing Record 12 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 13 of Set 12 | sao filipe
# Processing Record 14 of Set 12 | pierre
# Processing Record 15 of Set 12 | bako
# Processing Record 16 of Set 12 | marabba
# Processing Record 17 of Set 12 | barcelos
# Processing Record 18 of Set 12 | leningradskiy
# Processing Record 19 of Set 12 | camocim
# Processing Record 20 of Set 12 | birjand
# Processing Record 21 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 12 | orsha
# Processing Record 23 of Set 12 | shubarkuduk
# Processing Record 24 of Set 12 | maldonado
# Processing Record 25 of Set 12 | campo grande
# Processing Record 26 of Set 12 | williston
# Processing Record 27 of Set 12 | esperance
# Processing Record 28 of Set 12 | canutama
# Processing Record 29 of Set 12 | tommot
# Processing Record 30 of Set 12 | orgun
# City not found. Skipping...
# Processing Record 31 of Set 12 | innisfail
# Processing Record 32 of Set 12 | mayo
# Processing Record 33 of Set 12 | kurumkan
# Processing Record 34 of Set 12 | soyo
# Processing Record 35 of Set 12 | naron
# Processing Record 36 of Set 12 | iguguno
# Processing Record 37 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 12 | dandong
# Processing Record 39 of Set 12 | garissa
# Processing Record 40 of Set 12 | akyab
# Processing Record 41 of Set 12 | muriae
# Processing Record 42 of Set 12 | pisco
# Processing Record 43 of Set 12 | diamantino
# Processing Record 44 of Set 12 | ritchie
# Processing Record 45 of Set 12 | ambilobe
# Processing Record 46 of Set 12 | pacific grove
# Processing Record 47 of Set 12 | kuminskiy
# Processing Record 48 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 12 | viedma
# Processing Record 50 of Set 12 | hinton
# Processing Record 1 of Set 13 | praia da vitoria
# Processing Record 2 of Set 13 | gat
# Processing Record 3 of Set 13 | narsaq
# Processing Record 4 of Set 13 | chicama
# Processing Record 5 of Set 13 | kautokeino
# Processing Record 6 of Set 13 | tasiilaq
# Processing Record 7 of Set 13 | mocuba
# Processing Record 8 of Set 13 | kabanjahe
# Processing Record 9 of Set 13 | sinnamary
# Processing Record 10 of Set 13 | mareeba
# Processing Record 11 of Set 13 | ontario
# Processing Record 12 of Set 13 | presidencia roque saenz pena
# Processing Record 13 of Set 13 | norsup
# Processing Record 14 of Set 13 | ampanihy
# Processing Record 15 of Set 13 | surazh
# Processing Record 16 of Set 13 | korla
# Processing Record 17 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 18 of Set 13 | murmansk
# Processing Record 19 of Set 13 | ridgecrest
# Processing Record 20 of Set 13 | karasjok
# Processing Record 21 of Set 13 | kaohsiung
# Processing Record 22 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 13 | lucapa
# Processing Record 24 of Set 13 | jutai
# Processing Record 25 of Set 13 | tomatlan
# Processing Record 26 of Set 13 | copiapo
# Processing Record 27 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 28 of Set 13 | goderich
# Processing Record 29 of Set 13 | baker city
# Processing Record 30 of Set 13 | manakara
# Processing Record 31 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 13 | guarapari
# Processing Record 33 of Set 13 | conde
# Processing Record 34 of Set 13 | bonthe
# Processing Record 35 of Set 13 | vermilion
# Processing Record 36 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 13 | olafsvik
# Processing Record 38 of Set 13 | manono
# Processing Record 39 of Set 13 | acajutla
# Processing Record 40 of Set 13 | letka
# Processing Record 41 of Set 13 | nuevo progreso
# Processing Record 42 of Set 13 | ngunguru
# Processing Record 43 of Set 13 | yazman
# Processing Record 44 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 13 | marienburg
# Processing Record 46 of Set 13 | quesnel
# Processing Record 47 of Set 13 | sandpoint
# Processing Record 48 of Set 13 | moroni
# Processing Record 49 of Set 13 | loralai
# Processing Record 50 of Set 13 | ambon
# Processing Record 1 of Set 14 | umm kaddadah
# Processing Record 2 of Set 14 | morondava
# Processing Record 3 of Set 14 | pochutla
# Processing Record 4 of Set 14 | wanning
# Processing Record 5 of Set 14 | filingue
# Processing Record 6 of Set 14 | kitsuki
# Processing Record 7 of Set 14 | waconia
# Processing Record 8 of Set 14 | batemans bay
# Processing Record 9 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 10 of Set 14 | longview
# Processing Record 11 of Set 14 | ko samui
# Processing Record 12 of Set 14 | korgen
# Processing Record 13 of Set 14 | husavik
# Processing Record 14 of Set 14 | sibu
# Processing Record 15 of Set 14 | balkhash
# Processing Record 16 of Set 14 | voyvozh
# Processing Record 17 of Set 14 | jeremoabo
# Processing Record 18 of Set 14 | malartic
# Processing Record 19 of Set 14 | gillette
# Processing Record 20 of Set 14 | taltal
# Processing Record 21 of Set 14 | saint-denis
# Processing Record 22 of Set 14 | uwajima
# Processing Record 23 of Set 14 | sao felix do xingu
# Processing Record 24 of Set 14 | isangel
# Processing Record 25 of Set 14 | kyzyl-suu
# Processing Record 26 of Set 14 | izvoarele sucevei
# Processing Record 27 of Set 14 | havre-saint-pierre
# Processing Record 28 of Set 14 | savannakhet
# Processing Record 29 of Set 14 | uddiawan
# Processing Record 30 of Set 14 | caceres
# Processing Record 31 of Set 14 | naze
# Processing Record 32 of Set 14 | kaputa
# Processing Record 33 of Set 14 | cabo rojo
# Processing Record 34 of Set 14 | okandja
# City not found. Skipping...
# Processing Record 35 of Set 14 | lakes entrance
# Processing Record 36 of Set 14 | hirado
# Processing Record 37 of Set 14 | beauvais
# Processing Record 38 of Set 14 | funadhoo
# Processing Record 39 of Set 14 | esmeraldas
# Processing Record 40 of Set 14 | tocache
# Processing Record 41 of Set 14 | murakami
# Processing Record 42 of Set 14 | naruja
# Processing Record 43 of Set 14 | vanavara
# Processing Record 44 of Set 14 | barda
# Processing Record 45 of Set 14 | tucano
# Processing Record 46 of Set 14 | saveh
# Processing Record 47 of Set 14 | port hueneme
# Processing Record 48 of Set 14 | mehran
# Processing Record 49 of Set 14 | margate
# Processing Record 50 of Set 14 | rio esteban
# Processing Record 1 of Set 15 | mbanza-ngungu
# Processing Record 2 of Set 15 | oktyabrskoye
# Processing Record 3 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 4 of Set 15 | hyderabad
# Processing Record 5 of Set 15 | hami
# Processing Record 6 of Set 15 | amravati
# Processing Record 7 of Set 15 | arlit
# Processing Record 8 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 15 | balabac
# Processing Record 10 of Set 15 | areosa
# Processing Record 11 of Set 15 | grand-santi
# Processing Record 12 of Set 15 | posse
# Processing Record 13 of Set 15 | yar-sale
# Processing Record 14 of Set 15 | necochea
# Processing Record 15 of Set 15 | emilio carranza
# Processing Record 16 of Set 15 | plettenberg bay
# Processing Record 17 of Set 15 | araouane
# Processing Record 18 of Set 15 | sol-iletsk
# Processing Record 19 of Set 15 | yaan
# Processing Record 20 of Set 15 | oktyabrskiy
# Processing Record 21 of Set 15 | qasigiannguit
# Processing Record 22 of Set 15 | san ramon
# Processing Record 23 of Set 15 | kangaatsiaq
# Processing Record 24 of Set 15 | uruzgan
# Processing Record 25 of Set 15 | mykolayivka
# Processing Record 26 of Set 15 | basco
# Processing Record 27 of Set 15 | xingyi
# Processing Record 28 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 15 | pont-rouge
# Processing Record 30 of Set 15 | euclides da cunha
# Processing Record 31 of Set 15 | campo verde
# Processing Record 32 of Set 15 | pathein
# Processing Record 33 of Set 15 | arawa
# Processing Record 34 of Set 15 | ancud
# Processing Record 35 of Set 15 | yarmouth
# Processing Record 36 of Set 15 | dinguiraye
# Processing Record 37 of Set 15 | goba
# Processing Record 38 of Set 15 | la malbaie
# Processing Record 39 of Set 15 | waddan
# Processing Record 40 of Set 15 | sobolevo
# Processing Record 41 of Set 15 | te horo
# Processing Record 42 of Set 15 | nichinan
# Processing Record 43 of Set 15 | itoman
# Processing Record 44 of Set 15 | jipijapa
# Processing Record 45 of Set 15 | bud
# Processing Record 46 of Set 15 | ambulu
# Processing Record 47 of Set 15 | bellary
# Processing Record 48 of Set 15 | canitas
# City not found. Skipping...
# Processing Record 49 of Set 15 | mandalgovi
# Processing Record 50 of Set 15 | winnemucca
# Processing Record 1 of Set 16 | wajir
# Processing Record 2 of Set 16 | benguela
# Processing Record 3 of Set 16 | karratha
# Processing Record 4 of Set 16 | rennes
# Processing Record 5 of Set 16 | labuhan
# Processing Record 6 of Set 16 | bulungu
# Processing Record 7 of Set 16 | kasongo-lunda
# Processing Record 8 of Set 16 | kinsale
# Processing Record 9 of Set 16 | vuktyl
# Processing Record 10 of Set 16 | dolinsk
# Processing Record 11 of Set 16 | khandbari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
WeatherPy_Database_df = pd.DataFrame(city_data)

WeatherPy_Database_df.head(10)
# Out:
#              City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0  Guerrero Negro  27.9769 -114.0611       broken clouds    291.67        69
# 1     New Norfolk -42.7826  147.0587       broken clouds    281.87        63
# 2          Kodiak  57.7900 -152.4072    scattered clouds    279.66        61
# 3          Hobart -42.8794  147.3294    scattered clouds    282.07        87
# 4       Katherine -14.4667  132.2667           clear sky    298.33        50
# 5         Mataura -46.1927  168.8643       moderate rain    286.19        98
# 6         Lahaina  20.8783 -156.6825    scattered clouds    298.04        79
# 7      Butaritari   3.0707  172.7902     overcast clouds    300.56        71
# 8        Saldanha -33.0117   17.9442    scattered clouds    301.18        46
# 9    Puerto Ayora  -0.7393  -90.3518       broken clouds    300.13        89
#
#    Cloudiness  Wind Speed Country                 Date
# 0          81        8.15      MX  2022-05-16 16:57:42
# 1          66        3.98      AU  2022-05-16 16:57:43
# 2          27        2.41      US  2022-05-16 16:57:43
# 3          40        5.66      AU  2022-05-16 16:57:10
# 4           0        2.57      AU  2022-05-16 16:57:44
# 5          77        0.73      NZ  2022-05-16 16:57:45
# 6          46        1.69      US  2022-05-16 16:57:46
# 7          97        7.77      KI  2022-05-16 16:57:46
# 8          47        4.29      ZA  2022-05-16 16:57:47
# 9          74        1.34      EC  2022-05-16 16:55:56

# %%
# Convert Max Temperature from Kelvin to Fahrenheit
def kelvinToFahrenheit(kelvin):
    return kelvin * 1.8 - 459.67

#city_data_df["Max Temp"].replace()
 
kelvin = WeatherPy_Database_df["Max Temp"]
WeatherPy_Database_df["Max Temp"] = kelvinToFahrenheit(kelvin)

# %%
WeatherPy_Database_df.head(15)
# Out:
#                City      Lat       Lng Current Description  Max Temp  \
# 0    Guerrero Negro  27.9769 -114.0611       broken clouds    65.336
# 1       New Norfolk -42.7826  147.0587       broken clouds    47.696
# 2            Kodiak  57.7900 -152.4072    scattered clouds    43.718
# 3            Hobart -42.8794  147.3294    scattered clouds    48.056
# 4         Katherine -14.4667  132.2667           clear sky    77.324
# 5           Mataura -46.1927  168.8643       moderate rain    55.472
# 6           Lahaina  20.8783 -156.6825    scattered clouds    76.802
# 7        Butaritari   3.0707  172.7902     overcast clouds    81.338
# 8          Saldanha -33.0117   17.9442    scattered clouds    82.454
# 9      Puerto Ayora  -0.7393  -90.3518       broken clouds    80.564
# 10  Bambous Virieux -20.3428   57.7575    scattered clouds    75.452
# 11         Portland  45.5234 -122.6762     overcast clouds    60.818
# 12            Tiksi  71.6872  128.8694          light snow    19.004
# 13         Shushtar  32.0455   48.8567           clear sky   100.328
# 14      Yellowknife  62.4560 -114.3525       broken clouds    45.122
#
#     Humidity  Cloudiness  Wind Speed Country                 Date
# 0         69          81        8.15      MX  2022-05-16 16:57:42
# 1         63          66        3.98      AU  2022-05-16 16:57:43
# 2         61          27        2.41      US  2022-05-16 16:57:43
# 3         87          40        5.66      AU  2022-05-16 16:57:10
# 4         50           0        2.57      AU  2022-05-16 16:57:44
# 5         98          77        0.73      NZ  2022-05-16 16:57:45
# 6         79          46        1.69      US  2022-05-16 16:57:46
# 7         71          97        7.77      KI  2022-05-16 16:57:46
# 8         46          47        4.29      ZA  2022-05-16 16:57:47
# 9         89          74        1.34      EC  2022-05-16 16:55:56
# 10        73          40        5.14      MU  2022-05-16 16:55:08
# 11        70         100        2.24      US  2022-05-16 16:57:48
# 12        95         100        5.39      RU  2022-05-16 16:57:49
# 13        11           0        5.53      IR  2022-05-16 16:57:50
# 14        61          75        6.17      CA  2022-05-16 16:57:50

# %%
# Round Max Temperature 
WeatherPy_Database_df["Max Temp"] = WeatherPy_Database_df["Max Temp"].round(decimals=1)

# %%
WeatherPy_Database_df.head(15)
# Out:
#                City      Lat       Lng Current Description  Max Temp  \
# 0    Guerrero Negro  27.9769 -114.0611       broken clouds      65.3
# 1       New Norfolk -42.7826  147.0587       broken clouds      47.7
# 2            Kodiak  57.7900 -152.4072    scattered clouds      43.7
# 3            Hobart -42.8794  147.3294    scattered clouds      48.1
# 4         Katherine -14.4667  132.2667           clear sky      77.3
# 5           Mataura -46.1927  168.8643       moderate rain      55.5
# 6           Lahaina  20.8783 -156.6825    scattered clouds      76.8
# 7        Butaritari   3.0707  172.7902     overcast clouds      81.3
# 8          Saldanha -33.0117   17.9442    scattered clouds      82.5
# 9      Puerto Ayora  -0.7393  -90.3518       broken clouds      80.6
# 10  Bambous Virieux -20.3428   57.7575    scattered clouds      75.5
# 11         Portland  45.5234 -122.6762     overcast clouds      60.8
# 12            Tiksi  71.6872  128.8694          light snow      19.0
# 13         Shushtar  32.0455   48.8567           clear sky     100.3
# 14      Yellowknife  62.4560 -114.3525       broken clouds      45.1
#
#     Humidity  Cloudiness  Wind Speed Country                 Date
# 0         69          81        8.15      MX  2022-05-16 16:57:42
# 1         63          66        3.98      AU  2022-05-16 16:57:43
# 2         61          27        2.41      US  2022-05-16 16:57:43
# 3         87          40        5.66      AU  2022-05-16 16:57:10
# 4         50           0        2.57      AU  2022-05-16 16:57:44
# 5         98          77        0.73      NZ  2022-05-16 16:57:45
# 6         79          46        1.69      US  2022-05-16 16:57:46
# 7         71          97        7.77      KI  2022-05-16 16:57:46
# 8         46          47        4.29      ZA  2022-05-16 16:57:47
# 9         89          74        1.34      EC  2022-05-16 16:55:56
# 10        73          40        5.14      MU  2022-05-16 16:55:08
# 11        70         100        2.24      US  2022-05-16 16:57:48
# 12        95         100        5.39      RU  2022-05-16 16:57:49
# 13        11           0        5.53      IR  2022-05-16 16:57:50
# 14        61          75        6.17      CA  2022-05-16 16:57:50

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
WeatherPy_Database_df.to_csv(output_data_file, index_label="City_ID")
